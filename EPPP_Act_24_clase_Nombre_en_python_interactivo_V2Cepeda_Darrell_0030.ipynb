# %% [markdown]
# <a href="https://colab.research.google.com/github/DarrellCepeda128/ACT-24-clase-pelicula-Cepeda-Darrell-0030/blob/main/EPPP_Act_24_clase_Nombre_en_python_interactivo_V2Cepeda_Darrell_0030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/DarrellCepeda128/ACT-24-clase-pelicula-Cepeda-Darrell-0030/refs/heads/main/InfoClasePelicula.png)

# %%
# Crear una segunda instancia de la clase Pelicula
segunda_pelicula = Pelicula(
    titulo="Aventura en el Bosque",
    direccion="Carlos Ruiz",
    duracion="95 minutos",
    clasificacion="G"
)

# Mostrar los atributos de la segunda película
print(f"--- Detalles de la Segunda Película ---")
print(f"Título: {segunda_pelicula.titulo}")
print(f"Dirección: {segunda_pelicula.direccion}")
print(f"Duración: {segunda_pelicula.duracion}")
print(f"Clasificación: {segunda_pelicula.clasificacion}")

# Usar los métodos de la segunda película
segunda_pelicula.reproducir()
segunda_pelicula.calificar(4)

# Crear una lista de objetos Pelicula
lista_peliculas = [mi_pelicula, segunda_pelicula]

# Recorrer la lista y demostrar atributos y métodos para cada película
for i, peli in enumerate(lista_peliculas):
    print(f"\n--- Película {i+1}: {peli.titulo} ---")
    print(f"Dirección: {peli.direccion}")
    print(f"Duración: {peli.duracion}")
    print(f"Clasificación: {peli.clasificacion}")
    peli.reproducir()
    peli.pausar()
    peli.calificar(3) # Calificación de ejemplo

print("Programa elaborado por Cepeda Darrell NL = 10")
# Out:
# --- Detalles de la Segunda Película ---
# Título: Aventura en el Bosque
# Dirección: Carlos Ruiz
# Duración: 95 minutos
# Clasificación: G
# 🎬 Reproduciendo: Aventura en el Bosque. ¡Prepara las palomitas!
# ⭐ Has calificado a 'Aventura en el Bosque' con 4 estrellas.
#
# --- Película 1: El Gran Viaje ---
# Dirección: Ana García
# Duración: 120 minutos
# Clasificación: PG-13
# 🎬 Reproduciendo: El Gran Viaje. ¡Prepara las palomitas!
# ⏸️ La película 'El Gran Viaje' ha sido pausada.
# ⭐ Has calificado a 'El Gran Viaje' con 3 estrellas.
#
# --- Película 2: Aventura en el Bosque ---
# Dirección: Carlos Ruiz
# Duración: 95 minutos
# Clasificación: G
# 🎬 Reproduciendo: Aventura en el Bosque. ¡Prepara las palomitas!
# ⏸️ La película 'Aventura en el Bosque' ha sido pausada.
# ⭐ Has calificado a 'Aventura en el Bosque' con 3 estrellas.
# Programa elaborado por Cepeda Darrell NL = 10

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/DarrellCepeda128/ACT-24-clase-pelicula-Cepeda-Darrell-0030/refs/heads/main/InfoClasePelicula.PNG)
